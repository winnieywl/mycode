# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
# Define coordinates of where to start our map
# 
# hershey = [40.284, -76.649]
# disney = [28.385, -81.563]
# boulder = [40.015, -105.2705]
# kansascity = [39.099, -94.578]

start_location = [40.284, -76.649]

# Create the map
my_map = folium.Map(location = start_location,  # Latitude and Longitude of Map 
                    zoom_start = 13)            # how far out you want to start this map? Initial is 10

# Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7d7b7ccfcc9721c3265ad5cd1b685a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7d7b7ccfcc9721c3265ad5cd1b685a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c7d7b7ccfcc9721c3265ad5cd1b685a2 = L.map(
#                 &quot;map_c7d7b7ccfcc9721c3265ad5cd1b685a2&quot;,
#                 {
#                     center: [40.284, -76.649],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b51edd142a60984debddc34b5028f8ae = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c7d7b7ccfcc9721c3265ad5cd1b685a2);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Define the coordinates we want our markers to be at
hershey_hotel = [40.300, -76.659]     # famous hotel
hershey_park = [40.288, -76.654]   # family theme park
comics_and_paperback_plus = [40.179, -76.179]  # local comic shop


# Add markers to the map
# popup --> label for the Marker; click on the pins on the map!
folium.Marker(hershey_hotel, popup = 'Hershey Hotel').add_to(my_map)
folium.Marker(hershey_park, popup = 'Hershey Park').add_to(my_map)
folium.Marker(comics_and_paperback_plus, popup = 'Comics and Paperback Plus').add_to(my_map)

# change the icon on a marker (location of Hershey Factory)
# see more icons here: https://getbootstrap.com/docs/3.3/components/
folium.Marker([40.285, -76.650], popup = 'Hershey Factory', icon=folium.Icon(color="red", icon="info-sign")).add_to(my_map)

#Display the map
my_map

my_map.save("index.html")

# %%
start_location = [40.7143, -74.0118] 

my_map = folium.Map(location = start_location,  
                    zoom_start = 15) 

bnym = [40.7143, -74.0118]    
xian_ff = [40.7091773, -74.0093052]   
bj_duck_house = [40.7146382, -73.9985571]  
dim_sim = [40.7136218, -73.9970903]

folium.Marker(bnym, popup = 'BNY Mellon', icon=folium.Icon(color="green", icon="home")).add_to(my_map)
folium.Marker(xian_ff, popup = "Xi'An Famous Food", icon=folium.Icon(color="red", icon="cutlery")).add_to(my_map)
folium.Marker(bj_duck_house, popup = 'Beijing Duck House', icon=folium.Icon(color="red", icon="cutlery")).add_to(my_map)
folium.Marker(dim_sim, popup = 'Golden Unicorn Dim Sum', icon=folium.Icon(color="red", icon="cutlery")).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b975c7a9b9ff8403d51adc618847487 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b975c7a9b9ff8403d51adc618847487&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6b975c7a9b9ff8403d51adc618847487 = L.map(
#                 &quot;map_6b975c7a9b9ff8403d51adc618847487&quot;,
#                 {
#                     center: [40.7143, -74.0118],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8125e648fee61d6daea6cae2a8a0ffd9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b975c7a9b9ff8403d51adc618847487);
#
#
#             var marker_e25736daf6c0556378bc5929b9c1e150 = L.marker(
#                 [40.7143, -74.0118],
#                 {}
#             ).addTo(map_6b975c7a9b9ff8403d51adc618847487);
#
#
#             var icon_5509466755ef61f77e9774614093b3b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e25736daf6c0556378bc5929b9c1e150.setIcon(icon_5509466755ef61f77e9774614093b3b8);
#
#
#         var popup_e1e80e1f6a11b9372b582cb680e40e4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9c1036c498a780538341a08895b456b2 = $(`&lt;div id=&quot;html_9c1036c498a780538341a08895b456b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BNY Mellon&lt;/div&gt;`)[0];
#             popup_e1e80e1f6a11b9372b582cb680e40e4e.setContent(html_9c1036c498a780538341a08895b456b2);
#
#
#         marker_e25736daf6c0556378bc5929b9c1e150.bindPopup(popup_e1e80e1f6a11b9372b582cb680e40e4e)
#         ;
#
#
#
#
#             var marker_5ccdeda91b2728062823c0299207d67c = L.marker(
#                 [40.7091773, -74.0093052],
#                 {}
#             ).addTo(map_6b975c7a9b9ff8403d51adc618847487);
#
#
#             var icon_f130777838b5547ffa2ade7d7b5a4ea6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5ccdeda91b2728062823c0299207d67c.setIcon(icon_f130777838b5547ffa2ade7d7b5a4ea6);
#
#
#         var popup_aa49f1c8dd08eff977bbbe8961835f90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9f4e5d4f31f1a369bd186dbf36c0ab8c = $(`&lt;div id=&quot;html_9f4e5d4f31f1a369bd186dbf36c0ab8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Xi&#x27;An Famous Food&lt;/div&gt;`)[0];
#             popup_aa49f1c8dd08eff977bbbe8961835f90.setContent(html_9f4e5d4f31f1a369bd186dbf36c0ab8c);
#
#
#         marker_5ccdeda91b2728062823c0299207d67c.bindPopup(popup_aa49f1c8dd08eff977bbbe8961835f90)
#         ;
#
#
#
#
#             var marker_ba1ce6da6d508fff90bc74b27cda7968 = L.marker(
#                 [40.7146382, -73.9985571],
#                 {}
#             ).addTo(map_6b975c7a9b9ff8403d51adc618847487);
#
#
#             var icon_08ebd111fb24669324612ef7846e7a52 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ba1ce6da6d508fff90bc74b27cda7968.setIcon(icon_08ebd111fb24669324612ef7846e7a52);
#
#
#         var popup_5fac7cea5d874edc6615fc2e084301f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a412fbd9ba760c7a5d67d29e95877305 = $(`&lt;div id=&quot;html_a412fbd9ba760c7a5d67d29e95877305&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beijing Duck House&lt;/div&gt;`)[0];
#             popup_5fac7cea5d874edc6615fc2e084301f9.setContent(html_a412fbd9ba760c7a5d67d29e95877305);
#
#
#         marker_ba1ce6da6d508fff90bc74b27cda7968.bindPopup(popup_5fac7cea5d874edc6615fc2e084301f9)
#         ;
#
#
#
#
#             var marker_e7dab12929af5f328e1989af6c132d96 = L.marker(
#                 [40.7136218, -73.9970903],
#                 {}
#             ).addTo(map_6b975c7a9b9ff8403d51adc618847487);
#
#
#             var icon_ac2df5216f33d94ea7475bb12f6271ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e7dab12929af5f328e1989af6c132d96.setIcon(icon_ac2df5216f33d94e

# %%
start_location = [40.284, -76.649]

# Using polygon markers with colors instead of default markers
polygon_map = folium.Map(location = start_location, zoom_start = 13)

# points of interest
hershey_hotel = [40.300, -76.659]     # famous hotel
hershey_park = [40.288, -76.654]   # family theme park
comics_and_paperback_plus = [40.179, -76.179]  # local comic shop


# Add markers to the map
folium.RegularPolygonMarker(hershey_hotel, popup = 'Hershey Hotel', fill_color = '#00ff40',
                            number_of_sides = 3, radius = 10).add_to(polygon_map)
folium.RegularPolygonMarker(hershey_park, popup = 'Hershey Park', fill_color = '#bf00ff',
                            number_of_sides = 5, radius = 10).add_to(polygon_map)
folium.RegularPolygonMarker(comics_and_paperback_plus, popup = 'Comics and Paperback Plus', fill_color = '#ff0000',
                           number_of_sides = 8, radius = 10).add_to(polygon_map)

#Display the map
polygon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_751ce85b0b139a50776d3a8501cd105c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_751ce85b0b139a50776d3a8501cd105c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_751ce85b0b139a50776d3a8501cd105c = L.map(
#                 &quot;map_751ce85b0b139a50776d3a8501cd105c&quot;,
#                 {
#                     center: [40.284, -76.649],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4da004124cb2d982a834ea06d7771a6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_751ce85b0b139a50776d3a8501cd105c);
#
#
#             var regular_polygon_marker_5a45961782554dfe445b4372d24ba6ec = new L.RegularPolygonMarker(
#                 [40.3, -76.659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00ff40&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_751ce85b0b139a50776d3a8501cd105c);
#
#
#         var popup_591e943533aea795f88ebfbc999a9185 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b75db6d919b87428be0c0b5b318316a2 = $(`&lt;div id=&quot;html_b75db6d919b87428be0c0b5b318316a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hershey Hotel&lt;/div&gt;`)[0];
#             popup_591e943533aea795f88ebfbc999a9185.setContent(html_b75db6d919b87428be0c0b5b318316a2);
#
#
#         regular_polygon_marker_5a45961782554dfe445b4372d24ba6ec.bindPopup(popup_591e943533aea795f88ebfbc999a9185)
#         ;
#
#
#
#
#             var regular_polygon_marker_6c8bd7587e8f2b409cacdd5e1a8fe043 = new L.RegularPolygonMarker(
#                 [40.288, -76.654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#bf00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 5, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_751ce85b0b139a50776d3a8501cd105c);
#
#
#         var popup_b4f7a5b96d01365e96793475acc55480 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c1a64d79d615088d9e5eff3fad89cbda = $(`&lt;div id=&quot;html_c1a64d79d615088d9e5eff3fad89cbda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hershey Park&lt;/div&gt;`)[0];
#             popup_b4f7a5b96d01365e96793475acc55480.setContent(html_c1a64d79d615088d9e5eff3fad89cbda);
#
#
#         regular_polygon_marker_6c8bd7587e8f2b409cacdd5e1a8fe043.bindPopup(popup_b4f7a5b96d01365e96793475acc55480)
#         ;
#
#
#
#
#             var regular_polygon_marker_a9be09e2688a9b7b2899dc8acc8f7b27 = new L.RegularPolygonMarker(
#                 [40.179, -76.179],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 8, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_751ce85b0b139a50776d3a8501cd105c);
#
#
#         var popup_4431ddd281dea39aa07bcf284ee3a862 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_efa1cf05ea9629e7b5d4d65bd812b1b2 = $(`&lt;div id=&quot;html_efa1cf05ea9629e7b5d4d65bd812b1b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Comics and Paperback Plus&lt;/div&gt;`)[0];
#             popup_4431ddd281dea39aa07bcf284ee3a862.setContent(html_efa1cf05ea9629e7b5d4d65bd812b1b2);
#
#
#         regular_polygon_marker_a9be09e2688a9b7b2899dc8acc8f7b27.bindPopup(popup_4431ddd281dea39aa07bcf284ee3a862)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen moz

# %%
map_with_tiles = folium.Map(location = start_location, tiles = 'Stamen Toner')
map_with_tiles
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_601dfbb069f4f50760a90efa3f97ea56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_601dfbb069f4f50760a90efa3f97ea56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_601dfbb069f4f50760a90efa3f97ea56 = L.map(
#                 &quot;map_601dfbb069f4f50760a90efa3f97ea56&quot;,
#                 {
#                     center: [40.284, -76.649],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e64ee979cf3e122305a006100113f48 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_601dfbb069f4f50760a90efa3f97ea56);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
circle_map = folium.Map(location=[40.7143, -74.0118], tiles="Stamen Toner", zoom_start=15)

folium.Circle(
    radius=100,
    location=[40.7143, -74.0118],
    popup="BNY Mellon",
    color="crimson",
    fill=False,
).add_to(circle_map)

folium.CircleMarker(
    location=[40.7091773, -74.0093052],
    radius=50,
    popup="Xi'An Famous Food",
    color="#3186cc",
    fill = False
    #fill=True,
    #fill_color="#3186cc"
).add_to(circle_map)

folium.CircleMarker(
    location=[40.7146382, -73.9985571],
    radius=50,
    popup="Beijing Duck House",
    color="#3186cc",
    fill = False
    #fill=True,
    #fill_color="#3186cc"
).add_to(circle_map)

folium.CircleMarker(
    location=[40.7136218, -73.9970903],
    radius=50,
    popup="Golden Unicorn Dim Sum",
    color="#3186cc",
    fill = False
    #fill=True,
    #fill_color="#3186cc"
).add_to(circle_map)
circle_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c87ef4d73713a47b70360e68b27476f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c87ef4d73713a47b70360e68b27476f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2c87ef4d73713a47b70360e68b27476f = L.map(
#                 &quot;map_2c87ef4d73713a47b70360e68b27476f&quot;,
#                 {
#                     center: [40.7143, -74.0118],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3f2c6ca905cd53a6451ad3d2118d375 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c87ef4d73713a47b70360e68b27476f);
#
#
#             var circle_eaa475b34323d9f92ad3febb89c29526 = L.circle(
#                 [40.7143, -74.0118],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c87ef4d73713a47b70360e68b27476f);
#
#
#         var popup_f9f25c94339b4e8ca55958a70eda37db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_649c7e223e878da7da92e76b96ff6363 = $(`&lt;div id=&quot;html_649c7e223e878da7da92e76b96ff6363&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BNY Mellon&lt;/div&gt;`)[0];
#             popup_f9f25c94339b4e8ca55958a70eda37db.setContent(html_649c7e223e878da7da92e76b96ff6363);
#
#
#         circle_eaa475b34323d9f92ad3febb89c29526.bindPopup(popup_f9f25c94339b4e8ca55958a70eda37db)
#         ;
#
#
#
#
#             var circle_marker_f46f9fac9a460c31f66041fc17a614b0 = L.circleMarker(
#                 [40.7091773, -74.0093052],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c87ef4d73713a47b70360e68b27476f);
#
#
#         var popup_8f1d6faa22d598ae45021288f76712dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_df1067f52ef6075aa238b8cae5c813e5 = $(`&lt;div id=&quot;html_df1067f52ef6075aa238b8cae5c813e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Xi&#x27;An Famous Food&lt;/div&gt;`)[0];
#             popup_8f1d6faa22d598ae45021288f76712dd.setContent(html_df1067f52ef6075aa238b8cae5c813e5);
#
#
#         circle_marker_f46f9fac9a460c31f66041fc17a614b0.bindPopup(popup_8f1d6faa22d598ae45021288f76712dd)
#         ;
#
#
#
#
#             var circle_marker_1734ba6ffd60eda8cfd857fe45c6e976 = L.circleMarker(
#                 [40.7146382, -73.9985571],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c87ef4d73713a47b70360e68b27476f);
#
#
#         var popup_476cda041e130ccb272d7583a51fbc1c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a95531ede28903040067d0e1e3f184a6 = $(`&lt;div id=&quot;html_a95531ede28903040067d0e1e3f184a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beijing Duck House&lt;/div&gt;`)[0];
#             popup_476cda041e130ccb272d7583a51fbc1c.setContent(html_a95531ede28903040067d0e1e3f184a6);
#
#
#         circle_marker_1734ba6ffd60eda8cfd857fe45c6e976.bindPopup(popup_476cda041e130ccb272d7583a51fbc1c)
#         ;
#
#
#
#
#             var circle_marker_2520b6f218289aa226ffbff8bba82b28 = L.circleMarker(
#                 [40.7136218, -73.9970903],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;f

# %%
start_location = [40.7143, -74.0118] 

my_map = folium.Map(location = start_location,  
                    zoom_start = 15) 

bnym = [40.7143, -74.0118]    
xian_ff = [40.7091773, -74.0093052]   
bj_duck_house = [40.7146382, -73.9985571]  
dim_sim = [40.7136218, -73.9970903]

folium.Marker(bnym, popup = 'BNY Mellon', icon=folium.Icon(color="green", icon="home")).add_to(my_map)
folium.Marker(xian_ff, popup = "Xi'An Famous Food", icon=folium.Icon(color="red", icon="cutlery")).add_to(my_map)
folium.Marker(bj_duck_house, popup = 'Beijing Duck House', icon=folium.Icon(color="red", icon="cutlery")).add_to(my_map)
folium.Marker(dim_sim, popup = 'Golden Unicorn Dim Sum', icon=folium.Icon(color="red", icon="cutlery")).add_to(my_map)

my_map
