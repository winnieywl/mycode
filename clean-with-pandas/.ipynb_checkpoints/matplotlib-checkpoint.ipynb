# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# remove grid
plt.grid() # add greenline again 

# plot 1
plt.plot(x, y, label = "a")

# plot 2
plt.plot(x,y, label = "a") 

plt.style.use("ggplot")

plt.xlabel("Year")
plt.ylabel("Avg. Cheese Consumed Per American in Pounds")
plt.title("Americans Love Cheese")

plt.legend() # add legend


# save fig goes after any changes 
plt.show()

# %%
df = pd.read(csv)
list(df["Year"])

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.plot([-1, -4.5, 16, 23, 78, 22, 3])
plt.show()

# %%
plt.plot([-1, -4.5, 16, 23, 78, 22, 3], "ob") # ob input each point as a blue dot
plt.show()

# %%
# Use subplots() to specify titles and labels

       # generate the numbers 1 through 9 and convert that to a list
       # [1,2,3,4,5,6,7,8,9]
days = range(1, 9)
celsius_values = [25.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]

# specify 
fig, ax = plt.subplots()
ax.plot(days, celsius_values)
ax.set(xlabel='Day',
       ylabel='Temperature in Celsius',
       title='Temperature Graph')

plt.show()

# %%
# Use the same axes for multiple lines of data

days = list(range(1,9))
celsius_min = [19.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
celsius_max = [24.8, 28.9, 31.3, 33.0, 34.9, 35.6, 38.4, 39.2]

fig, ax = plt.subplots()

ax.set(xlabel='Day',
       ylabel='Temperature in Celsius',
       title='Temperature Graph')


ax.plot(days, celsius_min,
        days, celsius_min, "oy",
        days, celsius_max,
        days, celsius_max, "or")

plt.show()

# %%
# Make a bar plot of visitors over time (years)

        # this is a list comprehension; the contents of the list are being generated inside the list itself
        # "for every number between 2010 and 2021, add that number to this list"
years = [str(year) for year in range(2010, 2021)]
visitors = (1241, 50927, 162242, 222093, 
            665004, 2071987, 2460407, 3799215, 
            5399000, 5474016, 6003672)


plt.bar(years, visitors, color="green")

plt.xlabel("Years")
plt.ylabel("Values")
plt.title("Bar Chart Example")

plt.plot()
plt.show()

# %%
# Create randomly generated dummy data that follows a normal distribution
# https://en.wikipedia.org/wiki/Normal_distribution

gaussian_numbers = np.random.normal(size=10000)
gaussian_numbers

                          
plt.hist(gaussian_numbers, bins=20) # bins are the number of "columns" that make up the distribution curve
plt.title("Gaussian Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
$ pip install pyqrcode
$ pip install pypng
# Out:
#   Input In [13]
#     $ pip install pyqrcode
#     ^
# SyntaxError: invalid syntax

# %%
# in terminal, please type:
# python3 -m pip install pyqrcode
# python3 -m pip install pypng


# Import QRCode from pyqrcode
import pyqrcode
import png
from pyqrcode import QRCode
  
  
# String which represents the QR code
s = "https://github.com/winnieywl"
  
# Generate QR code
url = pyqrcode.create(s)
  
# Create and save the svg file naming "myqr.svg"
url.svg("myqr.svg", scale = 10)
  
# Create and save the png file naming "myqr.png"
url.png('myqr.png', scale = 15)
